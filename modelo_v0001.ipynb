# %% [markdown]
# <a href="https://colab.research.google.com/github/G2EJ-IC/IC.G2EJ/blob/main/modelo_v0001.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***Ernesto josé Guerrero González, IC, MSc(C), Esp.***

# %% [markdown]
# ![Isométricos Logo EJGG-IC CyC (300 x300 - EG).bmp](data:image/bmp;base64,...)
